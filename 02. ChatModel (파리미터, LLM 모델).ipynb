# %% [markdown]
# # ChatModel
#
# <br>
#
# ## LangChain 모델 유형
# - 랭체인 문서에 따르면 LLM과 Chat Model 클래스는 각각 다른 형태의 입력과 출력을 다루는 언어 모델을 나타냄
# - 이 두 모델은 각기 다른 특성과 용도를 가지고 있어, 사용자의 요구사항에 맞게 선택하여 사용
#
#     **일반적으로 LLM은 주로 단일 요청에 대한 복잡한 출력을 생성하는 데 적합한 반면, Chat Model은 사용자와의 상호작용을 통한 연속적인 대화 관리에 더 적합**
#
# <br>
#
# #### LLM
# - **기능: LLM 클래스는 텍스트 문자열을 입력으로 받아 처리한 후, 텍스트 문자열을 반환**
#   - 이 모델은 광범위한 언어 이해 및 텍스트 생성 작업에 사용
#     - 예) 문서 요약, 콘텐츠 생성, 질문에 대한 답변 생성 등 복잡한 자연어 처리 작업을 수행
#   - 예시: 사용자가 특정 주제에 대한 설명을 요청할 때, LLM은 주어진 텍스트 입력을 바탕으로 상세한 설명을 생성하여 반환
#
# <br>
#
# #### Chat Model
# - **기능: Chat Model 클래스는 메시지의 리스트를 입력으로 받고, 하나의 메시지를 반환**
#   - 이 모델은 대화형 상황에 최적화되어 있으며, 사용자와의 연속적인 대화를 처리하는 데 사용
#   - Chat Model은 대화의 맥락을 유지하면서 적절한 응답을 생성하는 데 중점
#   - 예시: 사용자가 챗봇과 대화하는 상황에서, 사용자의 질문과 이전 대화 내용을 고려하여 적절한 답변을 생성
#
# <br>
#
# ### LLM
# - 랭체인에서 Large Language Models (LLMs) 는 핵심 구성 요소로, 다양한 LLM 제공 업체와의 상호작용을 위한 표준 인터페이스를 제공
#
#   **랭체인이 직접 LLM을 제공하는 것이 아니라, OpenAI, Cohere, Hugging Face 등과 같은 다양한 LLM 제공 업체로부터 모델을 사용할 수 있게 하는 플랫폼 역할**
#
# <br>
#
# #### LLM 인터페이스의 특징
# - **표준화된 인터페이스**: 랭체인의 LLM 클래스는 사용자가 문자열을 입력으로 제공하면, 그에 대한 응답으로 문자열을 반환하는 표준화된 방식을 제공
#   - 이는 다양한 LLM 제공 업체 간의 호환성을 보장하며, 사용자는 복잡한 API 변환 작업 없이 여러 LLM을 쉽게 탐색하고 사용
#
# - **다양한 LLM 제공 업체 지원**: 랭체인은 OpenAI의 GPT 시리즈, Cohere의 LLM, Hugging Face의 Transformer 모델 등 다양한 LLM 제공 업체와의 통합을 지원
#   - 이를 통해 사용자는 자신의 요구 사항에 가장 적합한 모델을 선택하여 사용
#
# - **사용 사례**
#   - 다중 LLM 통합: 개발자는 랭체인의 LLM 클래스를 사용하여 여러 LLM 제공 업체의 모델을 하나의 애플리케이션 내에서 쉽게 통합
#     - 예) 특정 작업에 대해 OpenAI의 GPT 모델과 Cohere의 모델을 비교 평가하고, 성능이 더 우수한 모델을 선택
#   - 유연한 모델 전환: 프로젝트 요구 사항이 변경되거나 다른 LLM 제공 업체에서 더 적합한 모델이 제공될 경우, 랭체인의 표준 인터페이스를 통해 쉽게 모델을 전환
#     - 개발자가 더 나은 성능, 비용 효율성, 또는 기능적 요구 사항을 충족하는 모델로 유연하게 이동
#
# <br>
#
# ### Chat Model
# - **Chat Model 클래스는 랭체인에서 중요한 구성 요소로, 대화형 메시지를 입력으로 사용하고 대화형 메시지를 출력으로 반환하는 특수화된 LLM 모델**
#   - 일반 텍스트를 사용하는 대신 대화의 맥락을 포함한 메시지를 처리하며, 이를 통해 보다 더 자연스러운 대화를 가능하게 함
#
# <br>
#
# #### Chat Model 인터페이스
# - 대화형 입력과 출력: Chat Model은 대화의 연속성을 고려하여 입력된 메시지 리스트를 기반으로 적절한 응답 메시지를 생성
#   - 챗봇, 가상 비서, 고객 지원 시스템 등 대화 기반 서비스에 어울립니다.
#
# - 다양한 모델 제공 업체와의 통합: 랭체인은 OpenAI, Cohere, Hugging Face 등 다양한 모델 제공 업체와의 통합을 지원
#   - 이를 통해 개발자는 여러 소스의 Chat Models를 조합하여 활용
# - 다양한 작동 모드 지원: 랭체인은 동기(sync), 비동기(async), 배치(batching), 스트리밍(streaming) 모드에서 모델을 사용할 수 있는 기능을 제공
#   - 다양한 애플리케이션 요구사항과 트래픽 패턴에 따라 유연한 대응이 가능
#
# <br>
#
# #### LangChain의 LLM 모델 파라미터
# - 모델의 속성에 해당하는 모델 파라미터는 LLM의 출력을 조정하고 최적화하는데 사용되며, 모델이 생성하는 텍스트의 스타일, 길이, 정확도 등에 영향
#
#   - https://api.python.langchain.com/en/latest/langchain/index.html
#
#   (사용하는 모델이나 플랫폼에 따라 세부 내용은 차이)
#
#     - **Temperature**: 생성된 텍스트의 다양성을 조정.
#       - 값이 작으면 예측 가능하고 일관된 출력을 생성하는 반면, 값이 크면 다양하고 예측하기 어려운 출력을 생성
#     - **Max Tokens (최대 토큰 수)**: 생성할 최대 토큰 수를 지정. 생성할 텍스트의 길이를 제한.
#     - **Top P (Top Probability)**: **생성 과정에서 특정 확률 분포 내에서 상위 P% 토큰만을 고려하는 방식.**
#       - 출력의 다양성을 조정하는 데 도움
#     - **Frequency Penalty (빈도 패널티)**: 값이 클수록 이미 등장한 단어나 구절이 다시 등장할 확률을 감소.
#       - 반복을 줄이고 텍스트의 다양성을 증가시킬 수 있음. (0~1)
#     - **Presence Penalty (존재 패널티)**: 텍스트 내에서 단어의 존재 유무에 따라 그 단어의 선택 확률을 조정.
#       - 값이 클수록 아직 텍스트에 등장하지 않은 새로운 단어의 사용이 장려. (0~1)
#     - **Stop Sequences (정지 시퀀스)**: 특정 단어나 구절이 등장할 경우 생성을 멈추도록 설정.
#       - 출력을 특정 포인트에서 종료하고자 할 때 사용
#
# <br>
#
# 1. **모델 생성시 파라미터를 전달**
# - 모델 인스턴스 생성 시 또는 모델을 호출하는 시점에 파라미터를 인수로 제공함으로써, **해당 호출에 대해서만 파라미터 설정을 적용**
# - **특정한 호출에 대한 파라미터를 사용자가 직접 세밀하게 조정할 수 있으며, 다양한 설정을 실험하거나 특정 요청에 대해 최적화된 응답을 생성하는 데 유용**

# %%
from dotenv import load_dotenv
import os

load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import ChatOpenAI

# 모델 파라미터 설정
params = {
    "temperature": 0.7,         # 생성된 텍스트의 다양성 조정
    "max_tokens": 100,          # 생성할 최대 토큰 수    
    "frequency_penalty": 0.5,   # 이미 등장한 단어의 재등장 확률
    "presence_penalty": 0.5,    # 새로운 단어의 도입을 장려
    "stop": ["\n"]              # 정지 시퀀스 설정
}

# %%
model = ChatOpenAI(model="gpt-4o-mini", **params)
question = "태양계에서 가장 큰 행성은 무엇인가요?"
response = model.invoke(input=question)

print(response)
# Out:
# content='태양계에서 가장 큰 행성은 목성(Jupiter)입니다. 목성은 지구보다 훨씬 크며, 그 지름은 약 142,984킬로미터에 달합니다. 또한, 목성은 많은 위성을 가지고 있으며, 강력한 자기장을 형성하고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 20, 'total_tokens': 86, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Cd6H5YM5tYoj2seauw3ik2ewThaoU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--dd5329a9-57b6-45bb-a2c8-5718ba9f622d-0' usage_metadata={'input_tokens': 20, 'output_tokens': 66, 'total_tokens': 86, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# <br>
#
# 2. **모델 호출시 파라미터를 전달**

# %%
params = {
    "temperature": 0.7,         # 생성된 텍스트의 다양성 조정
    "max_tokens": 20,          # 생성할 최대 토큰 수    
}

response = model.invoke(input=question, **params)

print(response.content)
# Out:
# 태양계에서 가장 큰 행성은 목성(Jupiter)입니다. 목성은 지

# %% [markdown]
# <br>
#
# ### 추가 바인딩 (`bind`)
# - `bind` 메서드를 사용하는 방식의 장점은 특정 모델 설정을 기본값으로 사용하고자 할 때 유용하며, 특수한 상황에서 일부 파라미터를 다르게 적용하고 싶을 때 사용
# - 기본적으로 일관된 파라미터 설정을 유지하면서 상황에 맞춰 유연한 대응이 가능

# %% [markdown]
# <br>
#
# - `bind` 이전

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages([
    ("system", "이 시스템은 천문학 질문에 답변할 수 있습니다."),
    ("user", "{user_input}"),
])

model = ChatOpenAI(model="gpt-4o-mini", max_tokens=100)

messages = prompt.format_messages(user_input="태양계에서 가장 큰 행성은 무엇인가요?")

before_answer = model.invoke(messages)
print(before_answer.content)
# Out:
# 태양계에서 가장 큰 행성은 목성입니다. 목성은 지구보다 훨씬 큰 가스를 주로 구성한 거대한 행성으로, 지름은 약 139,822킬로미터에 달합니다. 또한, 목성은 강력한 자기장과 많은 위성을 가지고 있는 것으로 유명합니다.

# %% [markdown]
# <br>
#
# - 추가 파라미터 `bind` : 모델 호출 시 추가적인 인수를 전달

# %%
chain = prompt | model.bind(max_tokens=10)

after_answer = chain.invoke({"user_input": "태양계에서 가장 큰 행성은 무엇인가요?"})

print(after_answer.content)
# Out:
# 태양계에서 가장 큰 행성은 목

# %% [markdown]
# <br>
#
# ## 다양한 Chat Model
#
# <br>
#
# ### Claude (Anthropic)
# - https://console.anthropic.com/settings/billing
#
# ```bash
# $ pip install -U langchain-anthropic
# ```
#
# <br>
#
# - `.env`
#
# ```ini
# ANTHROPIC_API_KEY=your_api_key_here
# ```
#
# <br>
#
# - 모델 초기화
#
# ```python
# from langchain_anthropic import ChatAnthropic
#
# # 모델 로드
# llm = ChatAnthropic(
#     model="claude-3-haiku-20240307",
#     temperature=0,
#     max_tokens=200,
#     api_key="인증키 입력"
# )
# ```
#
# <br>
#
# - 메시지 구성
#
# ```python
# messages=[
#     {"role": "system", "content": "You are a helpful assistant."},
#     {"role": "user", "content": "LLM은 어떤 원리로 작동하나요? 100자 이내로 설명해주세요."},
# ]
# ```
#
# <br>
#
# - 모델 호출 및 응답 출력
#
# ```python
# ai_msg = llm.invoke(messages)
# ```
#
# <br>
#
# #### Gemini (Google)
# - https://aistudio.google.com/app/prompts/new_chat
#
# ```bash
# $ pip install -U langchain-google-genai
# ```
#
# <br>
#
# - `.env`
#
# ```ini
# GOOGLE_API_KEY=your_api_key_here
# ```
#
# <br>
#
# - 모델 초기화
#
# ```python
# from langchain_google_genai import ChatGoogleGenerativeAI
#
# # 모델 로드
# llm = ChatGoogleGenerativeAI(
#     model="gemini-1.5-flash",
#     temperature=0,
#     max_output_tokens=200,
#     google_api_key="인증키 입력"
# )
# ```
#
# <br>
#
# - 메시지 구성
#
# ```python
# messages=[
#     {"role": "system", "content": "You are a helpful assistant."},
#     {"role": "user", "content": "LLM은 어떤 원리로 작동하나요? 100자 이내로 설명해주세요."},
# ]
# ```
#
# <br>
#
# - 모델 호출 및 응답 출력
#
# ```python
# ai_msg = llm.invoke(messages)
# ```
#
# <br>
#
# <hr>
